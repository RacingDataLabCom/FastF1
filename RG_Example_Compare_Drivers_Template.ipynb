# %%
# !pip install fastf1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import fastf1
from matplotlib import pyplot as plt
from fastf1 import plotting

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
fastf1.Cache.enable_cache('Cache')

# %%
year1= 2023
gp1 = 'Bahrain'
event1 = 'R'
session_race1 = fastf1.get_session(year1, gp1, event1)
session_race1.load()
LapDrive1 = 50
driver1 ='PER'
driver1_laps = session_race1.laps.pick_driver(driver1)
driver1_specific_lap = driver1_laps[driver1_laps['LapNumber']==LapDrive1].iloc[0]
driver1_car = driver1_specific_lap.get_car_data()
# Out:
# /usr/local/lib/python3.9/dist-packages/fastf1/core.py:1492: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key, value in row.iteritems():
# /usr/local/lib/python3.9/dist-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /usr/local/lib/python3.9/dist-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /usr/local/lib/python3.9/dist-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...

# %%
year2= 2022
gp2 = 'Bahrain'
event2 = 'R'
session_race2 = fastf1.get_session(year2, gp2, event2)
session_race2.load()
LapDrive2 = 15
driver2 ='LEC'
driver2_laps = session_race2.laps.pick_driver(driver2)
driver2_specific_lap = driver2_laps[driver2_laps['LapNumber']==LapDrive2].iloc[0]
driver2_car = driver2_specific_lap.get_car_data()
# Out:
# /usr/local/lib/python3.9/dist-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /usr/local/lib/python3.9/dist-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /usr/local/lib/python3.9/dist-packages/fastf1/core.py:1492: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key, value in row.iteritems():
# /usr/local/lib/python3.9/dist-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...

# %%
plotting.setup_mpl()

fig, ax = plt.subplots(5,figsize=(14,10))

color_driver1 = "red"
color_driver2 = "blue"

ax[0].plot(driver2_car['Time'], driver2_car['Speed'], color=color_driver2)
ax[0].plot(driver1_car['Time'], driver1_car['Speed'], color=color_driver1)

ax[1].plot(driver2_car['Time'], driver2_car['RPM'], color=color_driver2)
ax[1].plot(driver1_car['Time'], driver1_car['RPM'], color=color_driver1)

ax[2].plot(driver2_car['Time'], driver2_car['nGear'], color=color_driver2)
ax[2].plot(driver1_car['Time'], driver1_car['nGear'], color=color_driver1)

ax[3].plot(driver2_car['Time'], driver2_car['Throttle'], color=color_driver2)
ax[3].plot(driver1_car['Time'], driver1_car['Throttle'], color=color_driver1)

ax[4].plot(driver2_car['Time'], driver2_car['Brake'], color=color_driver2)
ax[4].plot(driver1_car['Time'], driver1_car['Brake'], color=color_driver1)

ax[0].set_ylabel("Speed [km/h]")
ax[1].set_ylabel("RPM [#]")
ax[2].set_ylabel("Gear [#]")
ax[3].set_ylabel("Throttle [%]")
ax[4].set_ylabel("Brake [%]")

ax[0].get_xaxis().set_ticklabels([])
ax[1].get_xaxis().set_ticklabels([])
ax[2].get_xaxis().set_ticklabels([])
ax[3].get_xaxis().set_ticklabels([])
ax[4].get_xaxis().set_ticklabels([])

fig.align_ylabels()

fig.legend([driver1+" GP: "+gp1+" Year: "+str(year1)+" Lap Number: "+str(LapDrive1)+" Event: "+event1,driver2+" GP: "+gp2+" Year: "+str(year2)+" Lap Number: "+str(LapDrive2)+" Event: "+event2 ])

plt.subplots_adjust(left=0.06 ,right=0.99, top=0.9, bottom=0.05)
plt.show()

# %%
driver1_specific_lap
# Out:
# Time                      0 days 02:08:47.468000
# DriverNumber                                  11
# LapTime                   0 days 00:01:37.114000
# LapNumber                                     40
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:30.926000
# Sector2Time               0 days 00:00:42.564000
# Sector3Time               0 days 00:00:23.624000
# Sector1SessionTime        0 days 02:07:41.280000
# Sector2SessionTime        0 days 02:08:23.844000
# Sector3SessionTime        0 days 02:08:47.468000
# SpeedI1                                    236.0
# SpeedI2                                    236.0
# SpeedFL                                    281.0
# SpeedST                                    294.0
# IsPersonalBest                             False
# Compound                                    HARD
# TyreLife                                     6.0
# ...

# %%
driver2_specific_lap
# Out:
# Time                      0 days 01:05:57.048000
# DriverNumber                                  16
# LapTime                                      NaT
# LapNumber                                     10
# PitOutTime                0 days 01:04:09.214000
# PitInTime                                    NaT
# Sector1Time                                  NaT
# Sector2Time               0 days 00:00:49.713000
# Sector3Time               0 days 00:00:25.004000
# Sector1SessionTime                           NaT
# Sector2SessionTime        0 days 01:05:32.072000
# Sector3SessionTime        0 days 01:05:57.048000
# SpeedI1                                    219.0
# SpeedI2                                    214.0
# SpeedFL                                    288.0
# SpeedST                                    190.0
# IsPersonalBest                             False
# Compound                                    SOFT
# TyreLife                                     1.0
# ...
